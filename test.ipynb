# %%
# !pip install torch
# Out:
# ...
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#    ---------------------------------------- 0.0/110.9 MB ? eta -:--:--
#     --------------------------------------- 2.1/110.9 MB 44.6 MB/s eta 0:00:03
#    --- ------------------------------------ 11.0/110.9 MB 25.6 MB/s eta 0:00:04
#    ------- -------------------------------- 20.7/110.9 MB 32.2 MB/s eta 0:00:03
#    ---------- ----------------------------- 29.4/110.9 MB 33.9 MB/s eta 0:00:03
#    ------------- -------------------------- 37.2/110.9 MB 34.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 44.8/110.9 MB 34.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 49.8/110.9 MB 32.4 MB/s eta 0:00:02
#    ------------------- -------------------- 54.0/110.9 MB 30.8 MB/s eta 0:00:02
#    -------------------- ------------------- 57.4/110.9 MB 29.2 MB/s eta 0:00:02
#    --------------------- ------------------ 60.3/110.9 MB 27.6 MB/s eta 0:00:02
# ...

# %%
import torch

x = torch.randn(4)          # random values
probs = torch.softmax(x, dim=0)

print(probs)
print(probs.sum())          # = 1.0
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       3 x = torch.randn(4)          # random values
#       4 probs = torch.softmax(x, dim=0)
#
# ModuleNotFoundError: No module named 'torch'

# %%
# !pip show torch
# Out:
# Name: torch
# Version: 2.9.1
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org
# Author:
# Author-email: PyTorch Team <packages@pytorch.org>
# License: BSD-3-Clause
# Location: C:\Users\teeds\AppData\Local\Programs\Python\Python314\Lib\site-packages
# Requires: filelock, fsspec, jinja2, networkx, setuptools, sympy, typing-extensions
# Required-by:
